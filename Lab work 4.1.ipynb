# %% [markdown]
# # Завдання 1

# %%
import datetime
import requests
import statistics as st
today = datetime.date.today()
today_month = today.month
today_year = today.year
year_ago = (datetime.date.today() - datetime.timedelta(days = 365)).strftime('%Y%m%d')
list_with_values = {}

for i in range(365): # Получаем значения
    last_date = today - datetime.timedelta(days = i)
    par = {'valcode': 'USD', 'date': last_date.strftime('%Y%m%d')}
    req = requests.get('https://bank.gov.ua/NBUStatService/v1/statdirectory/exchange?json', params = par).json()
    list_with_values[req[0]['exchangedate']] = req[0]['rate']

# %%
set_1 = set()
for j in list_with_values: # Выбираем уникальные значения дат (комбинации месяца и года)
    set_1.add(j[3:])

list_with_values_2 = {} # Список по месяцам

for months in set_1: # Группируем значения по месяцам
    month_values = []
    for k in list_with_values:
        if k[3:] == months:
            month_values.append(list_with_values[k])
    list_with_values_2[months] = month_values

list_with_values_3 = {} # Список со средними
for l in list_with_values_2: # Заносим среднее по каждому месяцу в отдельный список
    list_with_values_3[l] = st.mean(list_with_values_2[l])

list_with_values_4 = {} # Список с СКО
for n in list_with_values_2:
    list_with_values_4[n] = st.pstdev(list_with_values_2[n])

list_with_values_5 = {} # Заносим среднее и СКО в один список
for d in list_with_values_3:
    list_with_values_5[d] = (list_with_values_3[d], list_with_values_4[d])   
    
for m in list_with_values_5: # Выводим результаты 
     print('Среднее за ', m, '-', list_with_values_5[m][0], ', СКО - ', list_with_values_5[m][1])
# Out:
# Среднее за  05.2020 - 26.814329032258065 , СКО -  0.13251436487816476
# Среднее за  07.2020 - 27.31283870967742 , СКО -  0.3582872713677414
# Среднее за  01.2020 - 24.119351612903227 , СКО -  0.3655099485614568
# Среднее за  02.2020 - 24.596524137931034 , СКО -  0.18439410128790462
# Среднее за  10.2019 - 24.808206516129033 , СКО -  0.22822706312692184
# Среднее за  06.2020 - 26.707343333333334 , СКО -  0.07162276492537516
# Среднее за  04.2020 - 27.224653333333332 , СКО -  0.2062352568198646
# Среднее за  12.2019 - 23.609435129032256 , СКО -  0.23882165159716187
# Среднее за  08.2020 - 27.558015 , СКО -  0.16901455639973723
# Среднее за  11.2019 - 24.367518633333333 , СКО -  0.26985906572536283
# Среднее за  08.2019 - 25.1289489 , СКО -  0.08432504846775943
# Среднее за  09.2019 - 24.769724166666666 , СКО -  0.4019072206089429
# Среднее за  03.2020 - 26.412293548387098 , СКО -  1.3987778886920756

# %%
import pickle
with open('Lab4.pickle', 'wb') as f:
    pickle.dump(list_with_values_5, f)

# %% [markdown]
# # Завдання 2

# %%
from bs4 import BeautifulSoup
import requests
conn = requests.get('https://www.unian.ua/science')
soup = BeautifulSoup(conn.text, 'html')
for link in soup.find_all('a'):
    print(link.text)
# Out:
# Зробити стартовою
#
#                                         Послуги
#
#
#                                                 Реклама на сайті
#
#
#                                                 Прес-центр
#
#
#                                                 Фотобанк
#
#
#                                                 Моніторинг
#
#
#                                                 Передплата новин
#
#
#                                         Соцмережі
#
#
#                                         Укр
#
#
# 							Рус
#
#
# 							Eng
#
#
#
#                                     Інформаційне агентство
#
#
#                         Головна
#
#
#                         Коронавірус
#
#
#                         Погода
#
#
#                         Вибори 2020
#
#
#                         Політика
#
#
#                         Економіка
#
#
#                         Війна
#
#
#                         Спецпроекти
#
#
#                                             Агро
#
#
#                                             Екологія
#
#
#                                             Зброя
#
#
#                                             Світ кидає палити
#
#
#                                             Страхування
#
#
#                                             День з Чемпіоном
#
#
#                         Регіони
#
#
#                                             Київ
#
#
#                                             Львів
#
#
#                                             Дніпро
#
#
#                                             Харків
#
#
#                                             Одеса
#
#
#                         Суспільство
#
#
#                         Спорт
#
#
#                         Світ
#
#
#                         Лайт
#
#
#                         Ігри
#
#
#                         Інциденти
#
#
#                         Здоров'я
#
#
#                         Туризм
#
#
#                         Курйози
#
#
#                         Рецепти
#
#
#                         Фото
#
#
#                         Відео
#
#
#                         Думки
#
#
#                         Публікації
#
#
#                         Інтерв'ю
#
#
#                         Зарубіжна преса
#
#
#                         Лонгріди
#
#
#                         Прес-центр
#
#
#                         Послуги
#
#
#                                             Реклама на сайті
#
#
#                                             Прес-центр
#
#
#                                             Фотобанк
#
#
#                                             Моніторинг
#
#
#                                             Передплата новин
#
# Архів
# Контакти
#
#                                                 Рус
#
# Укр
#
#                                                 Eng
#
#
#
#
#
# 							Впливає на супутники і комп'ютери: НАСА виявило гігантську аномалію над Землею (відео)
#
#
#
# 					У РНБО заявили про "масштабну кібератаку" РФ напередодні Дня Незалежності
#
#
#
# 					Унікальне фото: НАСА зробило знімок відразу двох явищ над Землею
#
#
# 					Хаббл зробив знімок "палаючої" галактики
#
#
# 					На Чернігівщині в лісі розкопали піч Х століття (фото)
#
#
# 					У самурайський екшен Ghost of Tsushima додадуть кооперативний режим (відео)
#
#
# 					Зорепад Персеїди 2020: з'явилися фото унікального явища
#
#
#             			Науковці змусили робота споживати спирт (відео)
#
#
#
#             			Впливає на супутники і комп'ютери: НАСА виявило гігантську аномалію над Землею (відео)
#
#
#
#             			У РНБО заявили про "масштабну кібератаку" РФ напередодні Дня Незалежності
#
#
#
#             			Вчені за допомогою генної терапії змогли майже повністю вилікувати герпес
#
#
#
#             			Сервіс Google Мапи показуватиме ландшафт місцевості (фото)
#
#
#
#             			Унікальне фото: НАСА зробило знімок відразу двох явищ над Землею
#
#
#
#             			Немає навіть у Європі: восени в Україні запустять унікальний сервіс
#
#
#
#             			Вчені назвали ще одну корисну властивість пива
#
#
#
#             			У магнітному полі над Південною Америкою утворилася небезпечна "вм'ятина" (відео)
#
#
#
#             			Експерти з кібербезпеки розповіли про нову схему шахрайства в Instagram
#
#
#
#             			У самурайський екшен Ghost of Tsushima додадуть кооперативний режим (відео)
#
#
#
#             			У світі вже понад 3 мільярдів геймерів
#
#
#
#             			iPhone 11 став найпопулярнішим смартфоном у світі
#
#
#
#             			У столичному метро ще на шести станціях з'явився 4G
#
#
#
#             			Фахівці назвали найкращі смартфони року
#
#
#
#             			"М'ясний гак": Хаббл сфотографував вражаючу галактику
#
#
#
#             			Telegram випустив оновлену версію програми з відеовикликами
#
#
#
#             			Спеціальний додаток Google буде повідомляти про ситуацію з готелями та транспортом під час коронавірусу
#
#
#
#             			Пентагон підтвердив, що створює групу для дослідження НЛО
#
#
#
#             			На Чернігівщині в лісі розкопали піч Х століття (фото)
#
#
#
#
#
#                                                         Стрічка новин
#
#
# 															Зеленський розповів, коли може відбутися наступна зустріч лідерів "нормандської четвірки"
#
#
# 																						Лайт
#
# 															Гороскоп на п'ятницю, 21 серпня: що чекає на Тельців, Левів, Козерогів та інші знаки Зодіаку
#
#
# 															У Києві завтра пройде дощ, температура до +29°
#
#
# 															Науковці змусили робота споживати спирт (відео)
#
#
# 															В Україні дорожчає долар: свіжий курс валют
#
#
# 																						Лайт
#
# 															Адвокат Єфремова заявив, що той не сидів за кермом авто в момент ДТП
#
#
# 															Зеленський прокоментував роботу Кравчука на чолі української делегації у ТКГ
#
#
# 															У Мінкульті розповіли, скільки потрібно грошей для реставрації пам'ятників культурної спадщини
#
#
# 																						Інтерв'ю
#
# 															Психолог Наталія Колодяжна: Якщо людина весь час перебуває в стресі, у напрузі, в поспіху, виконує багато завдань, потрібно дозволяти собі полінуватися і отримати від цього задоволення
#
#
# 															Киянин після сварки з дружиною підпалив магазин та вистрибнув з сьомого поверху (відео)
#
#
# 															Погода на завтра: в Україні буде спекотно і майже без опадів (карта)
#
#
# 																						Думка
#
# 															Від підпалу авто до Таращанського лісу. Чому в Україні може повторитися історія Гонгадзе
#
#
# 															Столичний фунікулер завтра відновить роботу після ремонту
#
#
# 															Кім Чен Ин віддав частину повноважень молодшій сестрі
#
#
# 																						Лайт
#
# 															Віка з "НеАнгелів" блиснула голою попою
#
#
# 															У дусі часу: збірна Іспанії оригінально оголосила склад на матч проти України (відео)
#
#
# 															Архіви Надзвичайної комісії, де зафіксовані злочини нацистів в період окупації Києва,
# вперше з'являться онлайн
#
#
# 															У Києві п'яний чоловік погрожує підірвати супермаркет - соцмережі (фото)
#
#
# 																						Туризм
#
# 															Нам море не тільки сниться: історії українців, які відпочили за кордоном і ні про що не шкодують
#
#
# 															Вода цвіте: у Києві заборонили купатися на більшості пляжів
#
#
# 															У НБУ розповіли про графік роботи банків на День Незалежності
#
#
# 															Nature: Світ може ніколи не дізнатися, чи кров’яна плазма лікує COVID-19
#
#
# 															У Києві назріває ще один конфлікт через прокат самокатів
#
#
# 															Севілья - Інтер: де дивитися фінал Ліги Європи
#
#
# 																						Вибори
#
# 															У Комітеті виборців заявили, що Зеленський використовує робочі поїздки для агітації за "Слугу народу"
#
#
# 															У глибокій комі: стало відомо про стан Навального
#
#
# 																						Лайт
#
# 															Кіану Рівз високо оцінив заходи безпеки через COVID-19 на зйомках "Матриці"
#
#
# 																						Аналітика
#
# 															Екологія на карантині: куди діваються відходи від боротьби з коронавірусом
#
#
# 															У Києві через пожежі різко підвищився рівень забрудненості повітря
#
#
# 															Лікарі змогли стабілізувати стан Навального
#
#
# 															Головні новини України за 20 серпня: перемир’я на Донбасі та антирекордні понад 2 тисячі нових випадків COVID-19
#
#
# 															Журналіст розповів, чому з коронавірусом краще не лягати в лікарню
#
#
# 																						Вибори
#
# 															На майбутніх виборах кандидати будуть активно маніпулювати екопроблемами, щоб отримати владу – політолог
#
#
# 															"Пацієнт не дав згоду на відвідування": до Навального в комі не пустили дружину (фото)
#
#
# 																						Лайт
#
# 															Тиждень моди в самому розпалі: як виглядати розкішно в похмуру погоду
#
#
# 															Посилення карантину в Одесі: розсадку пасажирів у транспорті контролюють посадочні команди (фото)
#
#
# 															Сім порад, як пестити чоловіка, щоб він отримав максимальне задоволення
#
#
# 															У Путіна відреагували на отруєння Навального
#
#
# 															МЗС готує пропозиції щодо подальшого розвитку відносин з Білоруссю
#
#
# 																						ігри
#
# 															За 10 років в World of Tanks зіграло 160 мільйонів осіб
#
#
# 															У Кабміні назвали строки концесії поромної переправи в порту "Чорноморськ"
#
#
# 																						Вибори
#
# 															Вибори на Донбасі: в  ОПОРІ наголосили на необхідності перегляду підстав для скасування
#
#
# 															Український бізнес готується до другої хвилі COVID-19 восени – нових звільнень не уникнути
#
#
# 															У Німеччині протягом трьох років будуть видавати 120 німцям по 120 євро на місяць
#
#
# 															Держстат назвав хвороби, від яких найчастіше помирають українці в цьому році
#
#
# 															Салат з огірків на зиму: рецепти смачної закуски
#
#
# 															Це Путін: у Навального вперше заговорили про винуватців отруєння
#
#
# 															"Його треба рятувати": лікар Навального вилетіла до Омська
#
#
# 															Херсонські фермери мають намір запатентувати місцевий кавун (відео)
#
#
# 															Особистий лікар хоче евакуювати Навального до Європи - ЗМІ
#
#
# 															"Гидливість до керівництва Росії": боєць ММА з Оренбургу хоче отримати українське громадянство
#
#
# 															Іноземець піймав дівчину на зрадах завдяки знанню російської мови
#
#
# 																						Лайт
#
# 															Названий зірковий склад "Піноккіо" Гільєрмо дель Торо
#
#
# 															Призначено дату судового розгляду обвинувального акту стосовно Мангера і Левіна
#
#
# 																						Лайт
#
# 															Ретроградний Меркурій: астролог розповіла, які небезпеки ця планета приготувала нам восени
#
#
# 															"Домашні тварини – не м'які іграшки": у Німеччині вводять нові правила для власників собак
#
#
# 															З початку карантину безробіття в Україні збільшилося на 67%
#
#
# 															Морпорт "Ольвія" офіційно передали в концесію
#
#
# 															Жертвами сильної спеки в Токіо стали понад 100 осіб
#
#
# 															Під час будівництва міжнародної дороги М-03 хочуть заощадити на якості матеріалів - ЗМІ
#
#
# 															У Херсоні в ніч перед візитом Зеленського взялися стелити новий асфальт (відео)
#
#
# 																						Лайт
#
# 															Голлівудський актор Стівен Фрай звернувся до білорусів (відео)
#
#
# 															Швейцарська Женева заплатить туристам, щоб заманити їх на відпочинок
#
#
# 															Стало зле після чашки чаю, а напередодні було стеження: все, що відомо про отруєння Навального (оновлюється)
#
#
# 															Голова Київської ОДА: ми перебуваємо на межі другої хвилі епідемії COVID-19
#
#
# 															Україна з Грузією підписали програму співробітництва між оборонними відомствами
#
#
# 															Українська розвідка відмовилась коментувати заяву ФСБ про спробу схопити ватажка бойовиків у Росії
#
#
# 																						Лайт
#
# 															З'явився трейлер безкоштовного фестивалю DC FanDome в режимі онлайн
#
#
# 															Санкціям ЄС проти Білорусі можуть і не дати "зелене світло" – журналіст
#
#
# 															Поліція РФ вимагає оглянути речі та багаж Навального
#
#
# 															В Україні продовжує падати сільгоспвиробництво
#
#
# 															"Хрещений батько" по-турецьки: застрелили найвпливовішого кримінального авторитета у світі Лоту Гулі
#
#
# 															National Geographic: Щеплення від COVID-19 можуть стати обов'язковими, як це буде відбуватися?
#
#
# 															Зеленський: Крим обов’язково повернеться до складу України
#
#
# 															"Нова смуга в історії клубу": Динамо представило домашню форму на наступний сезон (фото)
#
# Усі новини
# 2
# 3
# 4
# 5
# 6
# 7
# 476
#
#
#
#  Правилами користування сайтом
#  Політикою конфіденційності
